# %% [markdown]
# QUE.1 Write a python program to display all the header tags from wikipedia.org.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_Page')
bs = BeautifulSoup(html, "html.parser")
titles = bs.find_all(['h1', 'h2','h3','h4','h5','h6'])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading mw-first-heading" id="firstHeading" style="display: none">Main Page</h1>
#
# <h1><span class="mw-headline" id="Welcome_to_Wikipedia">Welcome to <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a></span></h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfl-h2"><span id="From_today.27s_featured_list"></span><span class="mw-headline" id="From_today's_featured_list">From today's featured list</span></h2>
#
# ...

# %% [markdown]
# QUE.2  Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release)
# and make data frame.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
url = 'https://www.imdb.com/search/title/?groups=top_100&sort=user_rating,desc'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
movie_name = []
rating = []
year = []

# %%
movie_data = soup.findAll('div', attrs = {'class' : 'lister-item mode-advanced'})

# %%
for store in movie_data:
    name = store.h3.a.text
    movie_name.append(name)
    
    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text
    year.append(year_of_release)
    
    rate = store.find('div', class_ = 'inline-block ratings-imdb-rating').text.replace('\n', '')
    rating.append(rate)

# %%
movie_DF = pd.DataFrame({'Name of movie': movie_name, 'year of release': year, 'Movie rating': rating,})

# %%
movie_DF
# Out:
#                                         Name of movie year of release  \
# 0                            The Shawshank Redemption          (1994)
# 1                                       The Godfather          (1972)
# 2                                     The Dark Knight          (2008)
# 3       The Lord of the Rings: The Return of the King          (2003)
# 4                                    Schindler's List          (1993)
# 5                              The Godfather: Part II          (1974)
# 6                                        12 Angry Men          (1957)
# 7                                        Pulp Fiction          (1994)
# 8                                           Inception          (2010)
# 9               The Lord of the Rings: The Two Towers          (2002)
# 10                                         Fight Club          (1999)
# 11  The Lord of the Rings: The Fellowship of the Ring          (2001)
# ...

# %% [markdown]
# QUE.3 Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of
# release) and make data frame.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
url = 'https://www.imdb.com/list/ls063915608/'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
movie_name = []
rating = []
year = []

# %%
movie_list = soup.findAll('div', attrs= {'class': "lister-item mode-detail"})

# %%
for store in movie_list:
    name = store.h3.a.text
    movie_name.append(name)
    
    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text
    year.append(year_of_release)
    
    rate = store.find('div', class_ = 'ipl-rating-star small').text.replace('\n','')
    rating.append(rate)

# %%
movie_DF = pd.DataFrame({'Name of movie': movie_name, 'Year of release': year, 'rating': rate,})

# %%
movie_DF
# Out:
#                         Name of movie Year of release rating
# 0                     Rang De Basanti          (2006)    7.6
# 1   Lagaan: Once Upon a Time in India          (2001)    7.6
# 2                      Dil Chahta Hai          (2001)    7.6
# 3                  Gangs of Wasseypur          (2012)    7.6
# 4            Zindagi Na Milegi Dobara          (2011)    7.6
# ..                                ...             ...    ...
# 95                 Kuch Kuch Hota Hai          (1998)    7.6
# 96                            Dhamaal          (2007)    7.6
# 97             Golmaal: Fun Unlimited          (2006)    7.6
# 98                            Aligarh          (2015)    7.6
# 99                              Earth          (1998)    7.6
#
# [100 rows x 3 columns]

# %% [markdown]
# QUE.4 ) Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://meesho.com/bags-ladies/pl/p7vbp'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
products_name = []
price_rate= []
discounts = []

# %%
products_list = soup.findAll('div', attrs = {'class': 'Card__BaseCard-sc-b3n78k-0 dUNFgg NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS NewProductCard__DetailCard_Desktop-sc-j0e7tu-2 fqvaeS'})

# %%
for store in products_list:
    name = store.p.text
    products_name.append(name)
    
    price_of_product = store.h5.text
    price_rate.append(price_of_product)
        
    discount_rate = store.find('div', class_ = 'Card__BaseCard-sc-b3n78k-0 iJCKg NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG NewProductCard__DiscountRow-sc-j0e7tu-15 kUcVjG').text
    discounts.append(discount_rate)

# %%
product_DF = pd.DataFrame({'Name of product': products_name, 'price of product': price_rate, 'discount rate': discounts,})

# %%
product_DF
# Out:
#                          Name of product price of product  \
# 0        Ravishing Classy Women Handbags             ₹950
# 1          Graceful Fancy Women Handbags             ₹528
# 2       Classic Versatile Women Handbags             ₹950
# 3      Ravishing Alluring Women Handbags             ₹384
# 4           Voguish Fancy Women Handbags            ₹1549
# 5   Ravishing Fashionable Women Handbags             ₹316
# 6         Classic Stylish Women Handbags            ₹3202
# 7      Graceful Versatile Women Handbags             ₹950
# 8          Elegant Classy Women Handbags             ₹950
# 9        Elegant Alluring Women Handbags            ₹2337
# 10        Trendy Alluring Women Handbags            ₹1320
# 11    Elegant Fashionable Women Handbags             ₹725
# 12       Classic Alluring Women Handbags             ₹518
# 13    Classic Fashionable Women Handbags             ₹620
# 14          Classic Fancy Women Handbags             ₹646
# ...

# %% [markdown]
# QUE 5. Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
#
#     A) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.icc-cricket.com/rankings/mens/player-rankings/odi'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
first_data=soup.find("div",attrs={"data-cricket-scope":"odi"}).find("div",class_="rankings-block__top-player").get_text(strip=True,separator=" ").split(" ")

other_data=soup.find("div",attrs={"data-cricket-scope":"odi"}).find_all("tr",class_="table-body")

final_lst=[]
final_lst.append(first_data)

for store in other_data:
    split_lst= store.get_text(strip=True,separator=" ").split(" ")
    final_lst.append(split_lst)

# %%
final_lst
# Out:
# [['1', '(0)', 'Babar', 'Azam', 'PAK', '891'],
#  ['2', '(0)', 'Virat', 'Kohli', 'IND', '811'],
#  ['3', '(0)', 'Imam-ul-Haq', 'PAK', '795'],
#  ['4', '(0)', 'Rohit', 'Sharma', 'IND', '791'],
#  ['5', '(0)', 'Quinton', 'de', 'Kock', 'SA', '789'],
#  ['6',
#   '(1)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'up',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Jonny',
#   'Bairstow',
#   'ENG',
#   '775'],
#  ['7',
#   '(1)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'down',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Ross',
#   'Taylor',
#   'NZ',
#   '775'],
#  ['8', '(0)', 'Rassie', 'van', 'der', 'Dussen', 'SA', '769'],
#  ['9', '(0)', 'David', 'Warner', 'AUS', '750'],
#  ['10', '(0)', 'Aaron', 'Finch', 'AUS', '745']]

# %% [markdown]
# QUE6. Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
first_data=soup.find("div",attrs={"data-cricket-scope":"wodi"}).find("div",class_= "rankings-block__top-player").get_text(strip=True,separator=" ").split(" ")

other_data=soup.find("div",attrs={"data-cricket-scope":"wodi"}).find_all("tr",class_="table-body")

final_lst=[]
final_lst.append(first_data)

for store in other_data:
    split_lst= store.get_text(strip=True,separator=" ").split(" ")
    final_lst.append(split_lst)

# %%
final_lst
# Out:
# [['1',
#   '(3)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'up',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Alyssa',
#   'Healy',
#   'AUS',
#   '785'],
#  ['2',
#   '(3)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'up',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Natalie',
#   'Sciver',
#   'ENG',
#   '750'],
#  ['3',
#   '(2)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'down',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Beth',
#   'Mooney',
#   'AUS',
#   '748'],
#  ['4',
#   '(2)',
#   'This',
#   'player',
#   'has',
#   'moved',
#   'down',
#   'in',
#   'the',
#   'rankings',
#   'since',
#   'the',
#   'previous',
#   'rankings',
#   'update',
#   'Laura',
#   'Wolvaardt',
#   'SA',
#   '722'],
#  ['5',
#   '(2)',
#   'This',
# ...

# %% [markdown]
# QUE.7 Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content
# and the code for the video from the link for the youtube video from the post.

# %%
from bs4 import BeautifulSoup
import requests
page1=requests.get('https://coreyms.com/')
page1
soup1=BeautifulSoup(page1.content)
soup1

data = []

for a in soup1.find_all('article'):     
    data.append({'heading':a.h2.text,'date':a.find('time',class_='entry-time').text,'content':a.find('div',class_='entry-content').text,'videolink':vl['src'] if (vl := a.find('iframe',class_='youtube-player')) else None})

# %%
data
# Out:
# [{'heading': 'Python Tutorial: Zip Files – Creating and Extracting Zip Archives',
#   'date': 'November 19, 2019',
#   'content': '\nIn this video, we will be learning how to create and extract zip archives. We will start by using the zipfile module, and then we will see how to do this using the shutil module. We will learn how to do this with single files and directories, as well as learning how to use gzip as well. Let’s get started…\n\n',
#   'videolink': 'https://www.youtube.com/embed/z0gguhEmWiY?version=3&rel=1&showsearch=0&showinfo=1&iv_load_policy=1&fs=1&hl=en-US&autohide=2&wmode=transparent'},
#  {'heading': 'Python Data Science Tutorial: Analyzing the 2019 Stack Overflow Developer Survey',
#   'date': 'October 17, 2019',
# ...

# %% [markdown]
# QUE.8 Write a python program to scrape house details from mentioned URL. It should include house title, location,
# area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar,
# Rajaji Nagar.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.nobroker.in/property/rent/chennai/multiple?searchParam=...&radius=2.0&sharedAccomodation=0&city=chennai&locality=Jaya%20Nagar,&locality=Rajaji%20Nagar,&locality=Indira%20Nagar'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
house_title = []
location_name = []
area_no = []
deposit_and_rent = []

# %%
house_list = soup.findAll('div', attrs = {'class': 'bg-white rounded-2 bg-clip-padding overflow-hidden my-1.2p mx-0.5p tp:border-b-0 tp:shadow-cardShadow tp:mt-0.5p tp:mx-0 tp:mb:1p hover:cursor-pointer nb__2_XSE'})

# %%
for store in house_list:
    name = store.find('div', class_ = 'mt-0.5p overflow-hidden overflow-ellipsis whitespace-nowrap max-w-70 text-gray-light leading-4 po:mb-0 po:max-w-95').text
    house_title.append(name)
    
    name_of_location = store.find('span', class_ = 'overflow-hidden overflow-ellipsis whitespace-nowrap max-w-80pe po:max-w-full').text
    location_name.append(name_of_location)
    
    no_of_area = store.find('div', class_ = 'flex flex-col w-33pe items-center border-r border-r-solid border-card-overview-border-color tp:w-half po:w-full last:border-r-1').text
    area_no.append(no_of_area)
    
    no_of_deposit = store.find('div', class_ = 'flex flex-col w-33pe items-center bo tp:w-half po:w-full border-r-0').text
    deposit_and_rent.append(no_of_deposit)

# %%
house_DF = pd.DataFrame({'Name of house':house_title, 'Nmae of Location':location_name, 'Area of Sqft':area_no, 'Deposit & Rent':deposit_and_rent,})

# %%
house_DF
# Out:
#                                         Name of house  \
# 0   Independent House, near govt school and backsi...
# 1                                 Bhuvaneshwari Nagar
# 2   Independent House, Gandhi st, near Sri Lakshmi...
# 3   lotus2/567 colony 3 cross street valluvar naga...
# 4   Independent House, Ottiambakkam Main Rd near T...
# 5    Jaya Nagar, near Ganesh Children's Clinic and...
# 6   Perumbakkam Road, Nookampalayam, Arasankazhani...
# 7           Vivekananda Nagar,  Near AAJ Super Market
# 8   Independent House, Mambakkam Village, Near Ind...
# 9   Independent House, Mambakkam Village, Near Ind...
# 10              Independent House, Jones basil avenue
# 11  Independent House, vivekanadha nagar main road...
# 12  Independent House, Vinoba Nagar NEAR, near Sri...
# 13  Independent House, Vivekandha Nagar Extn BOAT ...
# 14       Vivekandha Nagar  Near  Minminiz Play School
# 15       Basil Avenue Near R. V. Matriculation School
# ...

# %% [markdown]
# QUE.9 Write a python program to scrape mentioned details from dineout.co.in :
# i) Restaurant name
# ii) Cuisine
# iii) Location
# iv) Ratings
# v) Image URL

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.dineout.co.in/delhi-restaurants/buffet-special'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
restaurant_name = []
cuisine_and_price = []
location = []
ratings = []
image_url = []

# %%
restaurant_list = soup.findAll('div', attrs = {'class': 'restnt-main-wrap clearfix'})

# %%
for store in restaurant_list:
    name = store.a.text
    restaurant_name.append(name)
    
    name_of_cuisine = store.find('span', class_ = 'double-line-ellipsis').text
    cuisine_and_price.append(name_of_cuisine)
    
    location_name = store.find('div', class_= 'restnt-loc ellipsis').text
    location.append(location_name)
    
    no_of_ratings = store.find('div', class_= 'restnt-rating rating-4').text
    ratings.append(no_of_ratings)
    
    images = soup.findAll('img')

# %%
images_url = store.findAll('img', class_ = 'no-img')
image_url.append(images_url)

# %%
restaurant_DF = pd.DataFrame({'Name Of Restaurant':restaurant_name, 'Name Of cuisine & Price':cuisine_and_price, 'Name of Loaction':location, 'No Of Ratings':ratings,})

# %%
restaurant_DF
# Out:
#                   Name Of Restaurant  \
# 0                    Castle Barbeque
# 1                    Jungle Jamboree
# 2                    Castle Barbeque
# 3                         Cafe Knosh
# 4               The Barbeque Company
# 5                        India Grill
# 6                     Delhi Barbeque
# 7   The Monarch - Bar Be Que Village
# 8                         World Cafe
# 9                  Indian Grill Room
# 10                   Mad 4 Bar B Que
# 11                       Barbeque 29
# 12                        Glasshouse
#
#                               Name Of cuisine & Price  \
# 0      ₹ 2,000 for 2 (approx) | North Indian, Chinese
# 1   ₹ 1,400 for 2 (approx) | North Indian, Asian, ...
# 2      ₹ 2,000 for 2 (approx) | Chinese, North Indian
# 3       ₹ 3,000 for 2 (approx) | Italian, Continental
# 4      ₹ 1,700 for 2 (approx) | North Indian, Chinese
# 5      ₹ 2,400 for 2 (approx) | North Indian, Italian
# ...

# %%
images_url
# Out:
# [<img alt="Glasshouse" class="lazy-load-img no-img" data-gatype="RestaurantImageClick" data-src="https://im1.dineout.co.in/images/uploads/restaurant/sharpen/9/m/a/p9875-1645177960620f6c68ecfef.jpg?tr=tr:n-medium" data-url="/delhi/glasshouse-sector-50-gurgaon-9875" data-w-onclick="cardClickHandler"/>]

# %% [markdown]
# QUE10. Write a python program to scrape first 10 product details which include product name , price , Image URL from
# https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://www.bewakoof.com/women-t-shirts?ga_q=womens%20tshirts'
response = requests.get(url)
soup= BeautifulSoup (response.content, 'html.parser')

# %%
product_name = []
price = []
images = []

# %%
product_list = soup.findAll('div', attrs = {'class': "productCardBox"})
images_list = soup.findAll('img')

# %%
example = images_list[12]

# %%
example.attrs['src']
# Out:
# 'https://images.bewakoof.com/t320/dillinger-yellow-checkered-t-shirt-425382-1633607642-1.jpg'

# %%
exapmle = images_list[9]

# %%
example.attrs['src']
# Out:
# 'https://images.bewakoof.com/t320/dillinger-maroon-striped-t-shirt-425384-1633603954-1.jpg'

# %%
for store in product_list:
    name = store.h3.text
    product_name.append(name)
    
    price_of_product = store.find('span', class_ = 'discountedPriceText').text
    price.append(price_of_product)

# %%
product_DF = pd.DataFrame({'Name of Product':product_name, 'Price':price,})

# %%
product_DF
# Out:
#                                       Name of Product   Price
# 0                     Women's Grey Typography T-shirt   ₹ 479
# 1                         Women's White Solid T-shirt   ₹ 479
# 2                    Women's Black Typography T-shirt   ₹ 479
# 3                   Women's Yellow Typography T-shirt   ₹ 527
# 4                     Women's Pink Typography T-shirt   ₹ 527
# 5                          Women's Blue Solid T-shirt   ₹ 459
# 6                    Women's Green Typography T-shirt   ₹ 479
# 7                     Women's Pink Typography T-shirt   ₹ 479
# 8                    Women's Yellow Checkered T-shirt   ₹ 459
# 9                      Women's Maroon Striped T-shirt   ₹ 459
# 10                       Women Blue Solid Shirt Dress   ₹ 910
# 11                    Women's Black Solid Shirt Dress   ₹ 989
# 12                Women's Solid Resort Boxy Red Shirt   ₹ 449
# 13                       Women Blue Solid Shirt Dress   ₹ 910
# ...
